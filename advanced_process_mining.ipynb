# %%
from ocpa.objects.log.importer.csv import factory as ocpa_importer

# Import OCEL log from CSV file and apply OCEL importer
ocel = ocpa_importer.apply("ocel_log.csv")

# %%
# Case_ID,Activity,Timestamp,
# 1001,Payment Issue Reported,2025-01-10
# 1001,Document Verification,2025-01-11
# 1001,Payment Resolved,2025-01-12
# 1002,Payment Issue Reported,2025-01-15
# 1002,Document Verification,2025-01-16
# 1002,Payment Resolved,2025-01-17

# %%
from ocpa.objects.log.importer.csv import factory as ocpa_importer

ocel = ocpa_importer.apply("ocel_log.csv")
